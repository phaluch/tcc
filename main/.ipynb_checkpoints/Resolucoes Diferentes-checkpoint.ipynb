# %%
import  matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage
import cv2 as cv

# %%
i12 = ndimage.rotate(plt.imread('20220604_142852.jpg'),-90)
i6 = ndimage.rotate(plt.imread('20220604_142905.jpg'),-90)

# %%
i6.shape
# Out:
# (2880, 2160, 3)

# %%
i12.shape
# Out:
# (4032, 3024, 3)

# %%
my = 4032/2880
mx = 3024/2160

# %%
plt.rcParams["figure.figsize"] = (5,5)

# %%
plt.imshow(i6)

# %%
x = 1100
y = 700
dx = 75
dy = 75
plt.imshow(i6[y:(y+dy),x:(x+dx)])

# %%
cv.imwrite('i6_cropped.png',i6[y:(y+dy),x:(x+dx)])
# Out:
# True

# %%
plt.im

# %%
ymy = int(y*my)
ymydymy = ymy + int(dy*my)
xmx = int(x*mx)
xmxdxmx = xmx + int(dx*mx)

plt.imshow(i12[ymy:ymydymy,xmx:xmxdxmx])

# %%
cv.imwrite('i12_cropped.png',i12[ymy:ymydymy,xmx:xmxdxmx])
# Out:
# True

# %%
j1 = cv.imread('penrose1.jpeg',cv.IMREAD_GRAYSCALE)
j2 = cv.imread('penrose2.jpeg',cv.IMREAD_GRAYSCALE)

# %%
cv.imwrite('pen1.png',j1)
cv.imwrite('pen2.png',j2)
# Out:
# True

# %%
cv.imwrite('pen_delta.png',j1-j2)
# Out:
# True

# %%
plt.imshow(j1-j2)

# %%
plt.imshow(j1)

# %%
i8 = cv.imread('8x8.png',cv.IMREAD_GRAYSCALE)
i25 = cv.imread('25x25.png',cv.IMREAD_GRAYSCALE)

# %%
plt.imshow(i8)
